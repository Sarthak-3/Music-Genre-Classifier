# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import glob

# %% [markdown]
# #### Data Exploration

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Sarthak\\Documents\\Python\\Audio'

# %%
os.chdir('D:\Documents\Music\Data\genres_original')
os.getcwd()
# Out:
# 'D:\\Documents\\Music\\Data\\genres_original'

# %%
path = "D:\Documents\Music\Data\genres_original"
fileList = os.listdir(path)
genres = fileList
print(genres)
# Out:
# ['blues', 'blues_power_spectrogram.png', 'blues_time_domain.png', 'classical', 'classical_power_spectrogram.png', 'classical_time_domain.png', 'country', 'country_power_spectrogram.png', 'country_time_domain.png', 'disco', 'disco_power_spectrogram.png', 'disco_time_domain.png', 'hiphop', 'hiphop_power_spectrogram.png', 'hiphop_time_domain.png', 'jazz', 'jazz_power_spectrogram.png', 'jazz_time_domain.png', 'metal', 'metal_power_spectrogram.png', 'metal_time_domain.png', 'pop', 'pop_power_spectrogram.png', 'pop_time_domain.png', 'reggae', 'reggae_power_spectrogram.png', 'reggae_time_domain.png', 'rock', 'rock_power_spectrogram.png', 'rock_time_domain.png']

# %%
genres='blues classical country disco hiphop jazz metal pop reggae rock'.split()
genres
# Out:
# ['blues',
#  'classical',
#  'country',
#  'disco',
#  'hiphop',
#  'jazz',
#  'metal',
#  'pop',
#  'reggae',
#  'rock']

# %%
# Load an ogg vorbis file
filename = librosa.ex('trumpet')
y, sr = librosa.load(filename)

print(y)
print(sr)
# Out:
# [-1.40682457e-03 -4.46077698e-04 -4.10981564e-04 ...  7.96230779e-06
#  -3.04169989e-05  1.27650665e-05]
# 22050

# %%
fileList = os.listdir(os.path.join(path,genres[0]))
fileList[99].split('.wav')[0]
# Out:
# 'blues.00099'

# %%
path+'\\blues.00005'
# Out:
# 'D:\\Documents\\Music\\Data\\genres_original\\blues.00005'

# %%
# librosa.load(os.path.join(path, genre)+'\\blues.00005.wav',duration=5.0,sr=None,)

# %%
for i,genre in enumerate(genres):
    y, sr = librosa.load(os.path.join(path, genre)+'\\'+genre+'.00005.wav',duration=5.0,sr=None,)
    time=np.linspace(0,len(y)/sr,num=len(y))
    plt.figure(i+1)
    plt.title(genre+" Signal Wave")
    plt.yticks(ticks=[])
    plt.plot(time,y)
    plt.savefig(fname=genre+'_time_domain',quality=95,dpi=200)
    plt.show()
# Out:
# C:\Users\Sarthak\AppData\Local\Temp/ipykernel_10704/3481968007.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(fname=genre+'_time_domain',quality=95,dpi=200)
# C:\Users\Sarthak\AppData\Local\Temp/ipykernel_10704/3481968007.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(fname=genre+'_time_domain',quality=95,dpi=200)
# C:\Users\Sarthak\AppData\Local\Temp/ipykernel_10704/3481968007.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(fname=genre+'_time_domain',quality=95,dpi=200)
# ...

# %%
for i,genre in enumerate(genres):
    y,sr=librosa.load(os.path.join(path, genre)+'\\'+genre+'.00005.wav',duration=5.0,sr=None,)
    librosa.display.specshow(librosa.amplitude_to_db(abs(librosa.stft(y)),ref=1.0),
                         y_axis='log', x_axis='time')
    plt.title(genre.upper()+" Power Spectrogram")
    plt.colorbar(format='%+2.0f dB')
    plt.tight_layout()
    plt.savefig(fname=genre+'_power_spectrogram',quality=95,dpi=200)
    plt.show()
# Out:
# C:\Users\Sarthak\AppData\Local\Temp/ipykernel_10704/1633773310.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(fname=genre+'_power_spectrogram',quality=95,dpi=200)

# %% [markdown]
# #### Data Manipulation

# %%
pd.set_option('display.max_columns', 85)

# %%
path1 = "D:\Documents\Music\Data"

# %%
os.chdir('D:\Documents\Music\Data')
os.getcwd()
# Out:
# 'D:\\Documents\\Music\\Data'

# %%
pd.read_csv("features_3_sec.csv")
# Out:
#                filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0     blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1     blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2     blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3     blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4     blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# ...                 ...     ...               ...              ...       ...
# 9985   rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986   rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987   rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988   rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# 9989   rock.00099.9.wav   66149          0.369293         0.086759  0.050524
#
# ...

# %%
df = pd.read_csv("features_30_sec.csv")
df
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0    blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1    blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2    blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3    blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4    blues.00004.wav  661794          0.308526         0.087841  0.091529
# ..               ...     ...               ...              ...       ...
# 995   rock.00095.wav  661794          0.352063         0.080487  0.079486
# 996   rock.00096.wav  661794          0.398687         0.075086  0.076458
# 997   rock.00097.wav  661794          0.432142         0.075268  0.081651
# 998   rock.00098.wav  661794          0.362485         0.091506  0.083860
# 999   rock.00099.wav  661794          0.358401         0.085884  0.054454
#
#       rms_var  spectral_centroid_mean  spectral_centroid_var  \
# ...

# %%
df.drop('label',axis=1).values.shape
# Out:
# (1000, 59)

# %% [markdown]
# #### Making label a numeric column in the dataset

# %%
dict = {'blues' : 0, 
        'classical' : 1,
        'country' : 2, 
        'disco' : 3, 
        'hiphop' : 4, 
        'jazz' : 5, 
        'metal' : 6, 
        'pop' : 7, 
        'reggae' : 8, 
        'rock' : 9}

# %%
for i in dict.keys():
    print(i)
# Out:
# blues
# classical
# country
# disco
# hiphop
# jazz
# metal
# pop
# reggae
# rock

# %%
b = df.loc[251]['label']
b
# Out:
# 'country'

# %%
if 7 in [1,2,3]:
    print(1)
else:
    print(0)
# Out:
# 0

# %%
dict['classical']
# Out:
# 1

# %%
if(b in dict.keys()):
    print(dict[b])
# Out:
# 2

# %%
def get_label(x):
    if(x in dict.keys()):
        return(dict[x])

# and then call it inside the lambda function

df['clabels'] = df['label'].apply(lambda x: get_label(x))

# %%
df.tail()
# Out:
#            filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 995  rock.00095.wav  661794          0.352063         0.080487  0.079486
# 996  rock.00096.wav  661794          0.398687         0.075086  0.076458
# 997  rock.00097.wav  661794          0.432142         0.075268  0.081651
# 998  rock.00098.wav  661794          0.362485         0.091506  0.083860
# 999  rock.00099.wav  661794          0.358401         0.085884  0.054454
#
#       rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 995  0.000345             2008.149458          282174.689224
# 996  0.000588             2006.843354          182114.709510
# 997  0.000322             2077.526598          231657.968040
# 998  0.001211             1398.699344          240318.731073
# 999  0.000336             1609.795082          422203.216152
#
#      spectral_bandwidth_mean  spectral_bandwidth_var  rolloff_mean  \
# 995              2106.541053            88609.749506   4253.557033
# ...

# %%
var1 = df['clabels'] #6
var2 = df['length']

np.corrcoef(var1, var2)
# Out:
# array([[ 1.        , -0.06219435],
#        [-0.06219435,  1.        ]])

# %%
my_list = df.columns.to_list()[1:59]
my_list[0:5]
# Out:
# ['length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean', 'rms_var']
